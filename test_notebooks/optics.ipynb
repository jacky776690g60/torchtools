# %% [markdown]
# <h1 style="color: white; background: linear-gradient(43deg, #4158D0 0%, #d253c3 58%, #FB5959 100%); text-align: center; padding: 10px; box-shadow: 3px 3px 10px rgba(0,0,0,0.2); font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; border-radius: 5px; text-transform: capitalize;">
#   Testing Gimmicks
# </h1>

# %%
# %load_ext autoreload
# %autoreload 2 
# Reload all modules (except those excluded by %aimport) every time before executing the Python code typed.

import os, sys, time
import importlib
from pathlib import Path

import torch
import torch.nn as nn
from torchvision import transforms

NOTEBOOK_PATH = Path(os.getcwd())
sys.path.append(str(NOTEBOOK_PATH.parent.parent.resolve()))

import torchtools as tt
from torchtools import DaVinci, Mondrian, Optics, set_seeds

# %%
transforms = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# %%
train_dataloader, test_dataloader, classes, classes_to_idx = Optics.load_presplit_data(
    "../../../datasets/cifar10/",
    30,
    transforms,
    img_extension=".png",
    check_consistency=False
)
# Out:
# ImageFolder initialized after 0.2846 seconds. Found: 50000 samples.
# ImageFolder initialized after 0.0452 seconds. Found: 10000 samples.

# %%
train_dataloader, test_dataloader, classes, classes_to_idx = tt.gimmick.Optics.load_data(
    "../../../datasets/animals-10/",
    30,
    transforms,
    img_extension=".jpeg",
    check_consistency=False
)

fig = DaVinci.plot_batch_samples(train_dataloader, 3, 3)
fig
# Out:
# ImageFolder initialized after 0.2562 seconds. Found: 24209 samples.
